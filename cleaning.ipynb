# %%
import pandas as pd
import numpy as np
import scraping
import os
import string
from sklearn import preprocessing

# %%
data = []
nonStandardName = []
duplicates = [] 
notFound = [] 
errors = []

for file in os.listdir('data'):
    t1, t2, t3, t4, t5 = np.load('data/' + file, allow_pickle=True)
    data.extend(t1)
    nonStandardName.extend(t2)
    duplicates.extend(t3)
    notFound.extend(t4)
    errors.extend(t5)

# %% [markdown]
# ## Data Cleaning
# *Most players are scraped properly, but there are 4 types of exceptions found.*
# 1. **nonStandardName** - These are the players with middle names, punctuation within their names, etc.
# 2. **duplicates** - These are the players with the same names with the same final season. It is hard to differentiate the players using the code but easy by the eye
# 3. **notFound** - These are players who didn't play in the NCAA and entered the draft
# 4. **errors** - Any other errors

# %%
len(data)
# Out:
# 1435

# %% [markdown]
# **1. nonStandardName**

# %%
nonStandardName
# Out:
# [[2005, 'Alejandro Carmona Sanchez', 22, 'Undrafted', 80],
#  [2006, 'Marcus D. Williams', 20, 'Top30', 22],
#  [2007, 'Marcus E. Williams', 20, 'Top45', 33],
#  [2008, 'Luc Mbah a Moute', 21, 'Top45', 37],
#  [2009, 'Nando De Colo', 22, 'Top60', 53],
#  [2010, 'Anthony Mason, Jr.', 23, 'Undrafted', 80],
#  [2013, 'Tim Hardaway Jr.', 21, 'Top30', 24],
#  [2013, 'Trey McKinney Jones', 22, 'Undrafted', 80],
#  [2014, 'Walt Lemon, Jr.', 21, 'Undrafted', 80],
#  [2015, 'Kelly Oubre, Jr.', 19, 'Top15', 15],
#  [2015, 'Larry Nance, Jr.', 22, 'Top30', 27],
#  [2015, 'Derek Cooke, Jr.', 23, 'Undrafted', 80],
#  [2016, 'Wade Baldwin IV', 20, 'Top30', 17],
#  [2016, 'Gary Payton II', 23, 'Undrafted', 80],
#  [2016, 'James Webb III', 22, 'Undrafted', 80],
#  [2017, 'Derrick Walton, Jr.', 22, 'Undrafted', 80],
#  [2017, 'James Blackmon, Jr.', 22, 'Undrafted', 80],
#  [2017, 'George de Paula', 21, 'Undrafted', 80],
#  [2018, 'Marvin Bagley III', 19, 'Top15', 2],
#  [2018, 'Jaren Jackson, Jr.', 18, 'Top15', 4],
#  [2018, 'Wendell Carter, Jr.', 19, 'Top15', 7],
#  [2018, 'Michael Porter, Jr.', 19, 'Top15', 14],
#  [2018, 'Troy Brown, Jr.', 18, 'Top15', 15],
#  [2018, 'Melvin Frazier, Jr.', 21, 'Top45', 35],
#  [2018, 'Gary Trent, Jr.', 19, 'Top45', 37],
#  [2018, 'Bruce Brown, Jr.', 21, 'Top45', 42],
#  [2018, 'Bonzie Colson, Jr.', 22, 'Undrafted', 80],
#  [2019, 'Kevin Porter, Jr.', 19, 'Top30', 30],
#  [2019, 'Barry Brown, Jr.', 22, 'Undrafted', 80],
#  [2019, 'Anthony Lawrence, Jr.', 22, 'Undrafted', 80],
#  [2019, 'Galen Robinson, Jr.', 22, 'Undrafted', 80],
#  [2019, 'James Palmer, Jr.', 22, 'Undrafted', 80]]

# %%
# Urls obtained manually
urls = ['https://www.sports-reference.com/cbb/players/marcus-williams-1.html', 
        'https://www.sports-reference.com/cbb/players/marcus-williams-2.html',
        'https://www.sports-reference.com/cbb/players/luc-richard-mbah-a-moute-1.html',
        'https://www.sports-reference.com/cbb/players/anthony-mason-2.html',
        'https://www.sports-reference.com/cbb/players/tim-hardaway-jr-1.html',
        'https://www.sports-reference.com/cbb/players/trey-mckinney-jones-1.html', 
        'https://www.sports-reference.com/cbb/players/walt-lemon--1.html',
        'https://www.sports-reference.com/cbb/players/kelly-oubre-1.html',
        'https://www.sports-reference.com/cbb/players/larry-nance-2.html',
        'https://www.sports-reference.com/cbb/players/derek-cooke-1.html',
        'https://www.sports-reference.com/cbb/players/wade-baldwin-1.html',
        'https://www.sports-reference.com/cbb/players/gary-payton-2.html',
        'https://www.sports-reference.com/cbb/players/james-webb-1.html',
        'https://www.sports-reference.com/cbb/players/derrick-walton-1.html',
        'https://www.sports-reference.com/cbb/players/james-blackmon-1.html',
        'https://www.sports-reference.com/cbb/players/marvin-bagleyiii-1.html',
        'https://www.sports-reference.com/cbb/players/jaren-jacksonjr-1.html',
        'https://www.sports-reference.com/cbb/players/wendell-carterjr-1.html',
        'https://www.sports-reference.com/cbb/players/michael-porterjr-1.html',
        'https://www.sports-reference.com/cbb/players/troy-brown-5.html',
        'https://www.sports-reference.com/cbb/players/melvin-frazier-1.html',
        'https://www.sports-reference.com/cbb/players/gary-trentjr-1.html',
        'https://www.sports-reference.com/cbb/players/bonzie-colson-1.html',
        'https://www.sports-reference.com/cbb/players/kevin-porterjr-1.html',
        'https://www.sports-reference.com/cbb/players/barry-brown-1.html',
        'https://www.sports-reference.com/cbb/players/anthony-lawrencejr-1.html',
        'https://www.sports-reference.com/cbb/players/galen-robinsonjr-1.html',
        'https://www.sports-reference.com/cbb/players/james-palmer-1.html']

invalid = ['Alejandro Carmona Sanchez', 'Nando De Colo', 'George de Paula', 'Bruce Brown, Jr.']
newList = []
for row in nonStandardName:
    if row[1] in invalid:
        continue
    else:
        newList.append(row)

out = []
for i in range(len(urls)):
    player = newList[i]
    name, age, labelCat, labelPick = player[1], player[2], player[3], player[4]
    url = urls[i]
    row = scraping.scrapeRow(url)
    out.append([row[0], name, age] + row[2:] + [labelCat, labelPick])

# %%
data.extend(out)
len(data)
# Out:
# 1463

# %% [markdown]
# **2. duplicates**

# %%
duplicates
# Out:
# [[2005, 'David Lee', 22, 'Top30', 30],
#  [2007, 'Carl Landry', 23, 'Top45', 31],
#  [2008, 'Mike Taylor', 22, 'Top60', 55],
#  [2008, 'Ivan Johnson', 24, 'Undrafted', 80],
#  [2010, 'Jamar Smith', 23, 'Undrafted', 80],
#  [2011, 'Tristan Thompson', 20, 'Top15', 4],
#  [2011, 'Chris Wright', 22, 'Undrafted', 80],
#  [2011, 'Chris Wright', 21, 'Undrafted', 80],
#  [2012, 'Dion Waiters', 20, 'Top15', 4],
#  [2012, 'Chris Johnson', 22, 'Undrafted', 80],
#  [2014, 'Joe Harris', 22, 'Top45', 33],
#  [2015, 'Joe Young', 22, 'Top45', 43],
#  [2015, 'Marcus Thornton', 22, 'Top45', 45],
#  [2015, 'Greg Whittington', 22, 'Undrafted', 80],
#  [2015, 'Chris Walker', 20, 'Undrafted', 80],
#  [2016, 'Derrick Jones', 19, 'Undrafted', 80],
#  [2017, 'Dennis Smith', 19, 'Top15', 9],
#  [2017, 'Andrew White', 24, 'Undrafted', 80],
#  [2018, 'Zach Smith', 22, 'Undrafted', 80]]

# %%
# Urls obtained manually
urls = ['https://www.sports-reference.com/cbb/players/david-lee-1.html',
        'https://www.sports-reference.com/cbb/players/carl-landry-1.html',
        'https://www.sports-reference.com/cbb/players/tristan-thompson-2.html',
        'https://www.sports-reference.com/cbb/players/chris-wright-1.html',
        'https://www.sports-reference.com/cbb/players/chris-wright-2.html',
        'https://www.sports-reference.com/cbb/players/dion-waiters-1.html',
        'https://www.sports-reference.com/cbb/players/chris-johnson-1.html',
        'https://www.sports-reference.com/cbb/players/joe-harris--1.html',
        'https://www.sports-reference.com/cbb/players/joseph-young-1.html',
        'https://www.sports-reference.com/cbb/players/marcus-thornton-3.html',
        'https://www.sports-reference.com/cbb/players/chris-walker-6.html',
        'https://www.sports-reference.com/cbb/players/derrick-jonesjr-1.html',
        'https://www.sports-reference.com/cbb/players/dennis-smithjr-1.html',
        'https://www.sports-reference.com/cbb/players/andrew-whiteiii-1.html',
        'https://www.sports-reference.com/cbb/players/zach-smith-1.html']

invalid = ['Mike Taylor', 'Ivan Johnson', 'Jamar Smith', 'Greg Whittington']
newList = []
for row in nonStandardName:
    if row[1] in invalid:
        continue
    else:
        newList.append(row)

out = []
for i in range(len(urls)):
    player = newList[i]
    name, age, labelCat, labelPick = player[1], player[2], player[3], player[4]
    url = urls[i]
    row = scraping.scrapeRow(url)
    out.append([row[0], name, age] + row[2:] + [labelCat, labelPick])

# %%
data.extend(out)
len(data)
# Out:
# 1478

# %% [markdown]
# **3. notFound**

# %%
notFound
# Out:
# [[2005, 'Martell Webster', 18, 'Top15', 6],
#  [2005, 'Andrew Bynum', 17, 'Top15', 10],
#  [2005, 'Fran Vazquez', 22, 'Top15', 11],
#  [2005, 'Yaroslav Korolev', 18, 'Top15', 12],
#  [2005, 'Gerald Green', 19, 'Top30', 18],
#  [2005, 'Johan Petro', 19, 'Top30', 25],
#  [2005, 'Ian Mahinmi', 18, 'Top30', 28],
#  [2005, 'C.J. Miles', 18, 'Top45', 34],
#  [2005, 'Ricky Sanchez', 17, 'Top45', 35],
#  [2005, 'Ersan Ilyasova', 18, 'Top45', 36],
#  [2005, 'Monta Ellis', 19, 'Top45', 40],
#  [2005, 'Roko Ukic', 20, 'Top45', 41],
#  [2005, 'Mile Ilic', 21, 'Top45', 43],
#  [2005, 'Martynas Andriuskevicius', 19, 'Top45', 44],
#  [2005, 'Mickael Gelabale', 22, 'Top60', 48],
#  [2005, 'Andray Blatche', 18, 'Top60', 49],
#  [2005, 'Axel Hervelle', 22, 'Top60', 52],
#  [2005, 'Marcin Gortat', 21, 'Top60', 57],
#  [2005, 'Uros Slokar', 22, 'Top60', 58],
#  [2005, 'Cenk Akyol', 18, 'Top60', 59],
#  [2005, 'Marcelinho Huertas', 22, 'Undrafted', 80],
#  [2005, 'Deji Akindele', 22, 'Undrafted', 80],
#  [2005, "D'or Fischer", 23, 'Undrafted', 80],
#  [2005, 'Anthony Lever-Pedroza', 26, 'Undrafted', 80],
#  [2005, "Isma'il Muhammad", 21, 'Undrafted', 80],
#  [2005, 'Lucas Tischer', 22, 'Undrafted', 80],
#  [2005, 'Esteban Batista', 21, 'Undrafted', 80],
#  [2006, 'Andrea Bargnani', 20, 'Top15', 1],
#  [2006, "Patrick O'Bryant", 20, 'Top15', 9],
#  [2006, 'Saer Sene', 20, 'Top15', 10],
#  [2006, 'Thabo Sefolosha', 22, 'Top15', 13],
#  [2006, 'Oleksiy Pecherov', 20, 'Top30', 18],
#  [2006, 'Sergio Rodriguez', 20, 'Top30', 27],
#  [2006, 'Joel Freeland', 19, 'Top30', 30],
#  [2006, 'Kosta Perovic', 21, 'Top45', 38],
#  [2006, 'Marquinhos Vinicius', 22, 'Top45', 43],
#  [2006, 'Lior Eliyahu', 20, 'Top45', 44],
#  [2006, 'Vladimir Veremeenko', 21, 'Top60', 48],
#  [2006, 'Cheickh Samb', 21, 'Top60', 51],
#  [2006, 'Yotam Halperin', 22, 'Top60', 53],
#  [2006, 'Ejike Ugboaja', 21, 'Top60', 55],
#  [2006, 'Edin Bavcic', 22, 'Top60', 56],
#  [2006, 'Loukas Mavrokefalidis', 21, 'Top60', 57],
#  [2006, 'Damir Markota', 20, 'Top60', 59],
#  [2006, 'J.J. Barea', 22, 'Undrafted', 80],
#  [2006, 'Lou Amundson', 23, 'Undrafted', 80],
#  [2006, 'Jeremy Richardson', 22, 'Undrafted', 80],
#  [2006, 'Squeaky Johnson', 23, 'Undrafted', 80],
#  [2007, 'Jianlian Yi', 19, 'Top15', 6],
#  [2007, 'Marco Belinelli', 21, 'Top30', 18],
#  [2007, 'Rudy Fernandez', 22, 'Top30', 24],
#  [2007, 'Tiago Splitter', 22, 'Top30', 28],
#  [2007, 'Petteri Koponen', 19, 'Top30', 30],
#  [2007, 'Kyrylo Fesenko', 20, 'Top45', 38],
#  [2007, 'Stanko Barac', 20, 'Top45', 39],
#  [2007, 'Yue Sun', 21, 'Top45', 40],
#  [2007, 'Marc Gasol', 22, 'Top60', 48],
#  [2007, 'Renaldas Seibutis', 21, 'Top60', 50],
#  [2007, 'Brad Newley', 22, 'Top60', 54],
#  [2007, 'Georgios Printezis', 22, 'Top60', 58],
#  [2007, 'Milovan Rakovic', 22, 'Top60', 60],
#  [2007, 'Mirza Teletovic', 21, 'Undrafted', 80],
#  [2007, 'Gustavo Ayon', 22, 'Undrafted', 80],
#  [2007, 'Eric Dawson', 22, 'Undrafted', 80],
#  [2007, 'Cyril Awere', 22, 'Undrafted', 80],
#  [2007, 'Mirza Begic', 21, 'Undrafted', 80],
#  [2007, 'Carlos Morais', 21, 'Undrafted', 80],
#  [2007, 'Remi Yusuf', 23, 'Undrafted', 80],
#  [2008, 'Danilo Gallinari', 19, 'Top15', 6],
#  [2008, 'Alexis Ajinca', 20, 'Top30', 20],
#  [2008, 'Serge Ibaka', 18, 'Top30', 24],
#  [2008, 'Nicolas Batum', 19, 'Top30', 25],
#  [2008, 'Nikola Pekovic', 22, 'Top45', 31],
#  [2008, 'Omer Asik', 21, 'Top45', 36],
#  [2008, 'Nathan Jawai', 21, 'Top45', 41],
#  [2008, 'Ante Tomic', 21, 'Top45', 44],
#  [2008, 'Goran Dragic', 22, 'Top45', 45],
#  [2008, 'Henry Walker', 20, 'Top60', 47],
#  [2008, 'Tadija Dragicevic', 22, 'Top60', 53],
#  [2008, 'Semih Erden', 21, 'Top60', 60],
#  [2008, 'Timofey Mozgov', 21, 'Undrafted', 80],
#  [2008, 'Damjan Rudez', 22, 'Undrafted', 80],
#  [2008, 'Keith Brumbaugh', 22, 'Undrafted', 80],
#  [2008, 'Marcus Hubbard', 24, 'Undrafted', 80],
#  [2008, 'Julian Khazzouh', 22, 'Undrafted', 80],
#  [2008, 'Salah Mejri', 22, 'Undrafted', 80],
#  [2009, 'Ricky Rubio', 18, 'Top15', 5],
#  [2009, 'Victor Claver', 20, 'Top30', 22],
#  [2009, 'Omri Casspi', 21, 'Top30', 23],
#  [2009, 'Byron Mullens', 20, 'Top30', 24],
#  [2009, 'Rodrigue Beaubois', 21, 'Top30', 25],
#  [2009, 'Christian Eyenga', 20, 'Top30', 30],
#  [2009, 'Jeff Ayres', 22, 'Top45', 31],
#  [2009, 'Sergio Llull', 21, 'Top45', 34],
#  [2009, 'Jonas Jerebko', 22, 'Top45', 39],
#  [2009, 'Henk Norel', 21, 'Top60', 47],
#  [2009, 'Sergii Gladyr', 20, 'Top60', 49],
#  [2009, 'Patty Mills', 20, 'Top60', 55],
#  [2009, 'Emir Preldzic', 21, 'Top60', 57],
#  [2009, 'Joe Ingles', 21, 'Undrafted', 80],
#  [2009, 'Gigi Datome', 21, 'Undrafted', 80],
#  [2009, 'Vitor Faverani', 21, 'Undrafted', 80],
#  [2009, 'Viacheslav Kravtsov', 21, 'Undrafted', 80],
#  [2009, 'Garret Siler', 22, 'Undrafted', 80],
#  [2009, 'Josh Bostic', 22, 'Undrafted', 80],
#  [2009, 'Milos Teodosic', 22, 'Undrafted', 80],
#  [2009, 'Kyle Goldcamp', 23, 'Undrafted', 80],
#  [2010, 'Kevin Seraphin', 20, 'Top30', 17],
#  [2010, 'Tibor Pleiss', 20, 'Top45', 31],
#  [2010, 'Nemanja Bjelica', 22, 'Top45', 35],
#  [2010, "Da'Sean Butler", 22, 'Top45', 42],
#  [2010, 'Paulao Prestes', 22, 'Top45', 45],
#  [2010, 'Latavious Williams', 21, 'Top60', 48],
#  [2010, 'Ryan Richards', 19, 'Top60', 49],
#  [2010, 'Pape Sy', 22, 'Top60', 53],
#  [2010, 'Ish Smith', 21, 'Undrafted', 80],
#  [2010, 'Boban Marjanovic', 21, 'Undrafted', 80],
#  [2010, 'Alexey Shved', 21, 'Undrafted', 80],
#  [2010, 'Miroslav Raduljica', 22, 'Undrafted', 80],
#  [2010, 'Tim Ohlbrecht', 21, 'Undrafted', 80],
#  [2010, 'Stephen Dennis', 22, 'Undrafted', 80],
#  [2010, 'Matt Rogers', 22, 'Undrafted', 80],
#  [2010, 'Billy Rush', 22, 'Undrafted', 80],
#  [2010, 'Corey Webster', 21, 'Undrafted', 80],
#  [2011, 'Enes Kanter', 19, 'Top15', 3],
#  [2011, 'Jonas Valanciunas', 19, 'Top15', 5],
#  [2011, 'Jan Vesely', 21, 'Top15', 6],
#  [2011, 'Bismack Biyombo', 18, 'Top15', 7],
#  [2011, 'Donatas Motiejunas', 20, 'Top30', 20],
#  [2011, 'Nikola Mirotic', 20, 'Top30', 23],
#  [2011, 'Bojan Bogdanovic', 22, 'Top45', 31],
#  [2011, 'Jeremy Tyler', 20, 'Top45', 39],
#  [2011, 'Davis Bertans', 18, 'Top45', 42],
#  [2011, 'Milan Macvan', 21, 'Top60', 54],
#  [2011, "E'Twaun Moore", 22, 'Top60', 55],
#  [2011, 'Chu Maduabum', 20, 'Top60', 56],
#  [2011, 'Tanguy Ngombo', 21, 'Top60', 57],
#  [2011, 'Adam Hanga', 22, 'Top60', 59],
#  [2011, 'Mindaugas Kuzminskas', 21, 'Undrafted', 80],
#  [2011, 'Dairis Bertans', 21, 'Undrafted', 80],
#  [2011, 'Zoran Dragic', 22, 'Undrafted', 80],
#  [2011, 'Jake Anderson', 24, 'Undrafted', 80],
#  [2011, 'Mike Dunigan', 21, 'Undrafted', 80],
#  [2012, 'Thomas Robinson', 21, 'Top15', 5],
#  [2012, 'Evan Fournier', 19, 'Top30', 20],
#  [2012, 'Tomas Satoransky', 20, 'Top45', 32],
#  [2012, 'Bernard James', 27, 'Top45', 33],
#  [2012, 'Kostas Papanikolaou', 21, 'Top60', 48],
#  [2012, "Kyle O'Quinn", 22, 'Top60', 49],
#  [2012, 'Izzet Turkyilmaz', 22, 'Top60', 50],
#  [2012, 'Ognen Kuzmic', 22, 'Top60', 52],
#  [2012, 'Furkan Aldemir', 20, 'Top60', 53],
#  [2012, 'Tornike Shengelia', 20, 'Top60', 54],
#  [2012, 'Tomislav Zubcic', 22, 'Top60', 56],
#  [2012, 'Ilkan Karaman', 22, 'Top60', 57],
#  [2012, "Toure' Murry", 22, 'Undrafted', 80],
#  [2012, 'Nicolas Laprovittola', 22, 'Undrafted', 80],
#  [2012, 'Josh Magette', 22, 'Undrafted', 80],
#  [2012, "D'Aundray Brown", 23, 'Undrafted', 80],
#  [2012, 'Tu Holloway', 22, 'Undrafted', 80],
#  [2013, 'Giannis Antetokounmpo', 18, 'Top15', 15],
#  [2013, 'Lucas Nogueira', 20, 'Top30', 16],
#  [2013, 'Dennis Schroder', 19, 'Top30', 17],
#  [2013, 'Sergey Karasev', 19, 'Top30', 19],
#  [2013, 'Rudy Gobert', 21, 'Top30', 27],
#  [2013, 'Livio Jean-Charles', 19, 'Top30', 28],
#  [2013, 'Nemanja Nedovic', 22, 'Top30', 30],
#  [2013, 'Alex Abrines', 19, 'Top45', 32],
#  [2013, 'Ricky Ledo', 20, 'Top45', 43],
#  [2013, 'Marko Todorovic', 21, 'Top45', 45],
#  [2013, 'Raulzinho Neto', 21, 'Top60', 47],
#  [2013, 'Joffrey Lauvergne', 21, 'Top60', 55],
#  [2013, 'Bojan Dubljevic', 21, 'Top60', 59],
#  [2013, 'Janis Timma', 20, 'Top60', 60],
#  [2013, 'Matt Dellavedova', 22, 'Undrafted', 80],
#  [2013, 'Reginald Becton', 22, 'Undrafted', 80],
#  [2013, 'Jordan Henriquez', 23, 'Undrafted', 80],
#  [2013, 'Nicolo Melli', 22, 'Undrafted', 80],
#  [2013, 'Daniel Theis', 21, 'Undrafted', 80],
#  [2014, 'Dante Exum', 18, 'Top15', 5],
#  [2014, 'Dario Saric', 20, 'Top15', 12],
#  [2014, 'Jusuf Nurkic', 19, 'Top30', 16],
#  [2014, 'Bruno Caboclo', 18, 'Top30', 20],
#  [2014, 'Clint Capela', 20, 'Top30', 25],
#  [2014, 'Bogdan Bogdanovic', 21, 'Top30', 27],
#  [2014, 'Kyle Anderson', 20, 'Top30', 30],
#  [2014, 'Damien Inglis', 19, 'Top45', 31],
#  [2014, "Johnny O'Bryant", 21, 'Top45', 36],
#  [2014, 'Nikola Jokic', 19, 'Top45', 41],
#  [2014, 'Edy Tavares', 22, 'Top45', 43],
#  [2014, 'Thanasis Antetokounmpo', 21, 'Top60', 51],
#  [2014, 'Vasilje Micic', 20, 'Top60', 52],
#  [2014, 'Alessandro Gentile', 21, 'Top60', 53],
#  [2014, 'Nemanja Dangubic', 21, 'Top60', 54],
#  [2014, 'Devyn Marble', 21, 'Top60', 56],
#  [2014, 'Louis Labeyrie', 22, 'Top60', 57],
#  [2014, 'Cristiano Felicio', 21, 'Undrafted', 80],
#  [2014, 'Mitchell Creek', 22, 'Undrafted', 80],
#  [2014, 'Ronald Roberts', 22, 'Undrafted', 80],
#  [2014, 'Fuquan Edwin', 22, 'Undrafted', 80],
#  [2014, 'Stephen Holt', 22, 'Undrafted', 80],
#  [2014, 'John Petrucelli', 21, 'Undrafted', 80],
#  [2014, 'James McAdoo', 21, 'Undrafted', 80],
#  [2014, 'Maxi Kleber', 22, 'Undrafted', 80],
#  [2014, 'Axel Toupane', 21, 'Undrafted', 80],
#  [2014, 'Norvel Pelle', 21, 'Undrafted', 80],
#  [2014, 'Yuki Togashi', 20, 'Undrafted', 80],
#  [2015, "D'Angelo Russell", 19, 'Top15', 2],
#  [2015, 'Kristaps Porzingis', 19, 'Top15', 4],
#  [2015, 'Mario Hezonja', 20, 'Top15', 5],
#  [2015, 'Emmanuel Mudiay', 19, 'Top15', 7],
#  [2015, 'Nikola Milutinov', 20, 'Top30', 26],
#  [2015, 'Cedi Osman', 20, 'Top45', 31],
#  [2015, 'Willy Hernangomez', 21, 'Top45', 35],
#  [2015, 'Juan Vaulet', 19, 'Top45', 39],
#  [2015, 'Arturas Gudaitis', 22, 'Top60', 47],
#  [2015, 'Marcus Eriksson', 21, 'Top60', 50],
#  [2015, 'Satnam Singh', 19, 'Top60', 52],
#  [2015, 'Dom Pointer', 23, 'Top60', 53],
#  [2015, 'Daniel Diez', 22, 'Top60', 54],
#  [2015, 'Nikola Radicevic', 21, 'Top60', 57],
#  [2015, 'Dimitrios Agravanis', 20, 'Top60', 59],
#  [2015, 'Luka Mitrovic', 22, 'Top60', 60],
#  [2015, 'Nicolas Brussino', 22, 'Undrafted', 80],
#  [2015, "Royce O'Neale", 22, 'Undrafted', 80],
#  [2015, "Le'Bryan Nash", 22, 'Undrafted', 80],
#  [2015, 'Shawn Dawson', 21, 'Undrafted', 80],
#  [2015, 'Yannis Morin', 21, 'Undrafted', 80],
#  [2015, 'Vincent Poirier', 21, 'Undrafted', 80],
#  [2015, 'Juan Toscano-Anderson', 22, 'Undrafted', 80],
#  [2015, 'Dez Wells', 23, 'Undrafted', 80],
#  [2015, 'Ding Yanyuhang', 21, 'Undrafted', 80],
#  [2015, 'Luis Montero', 22, 'Undrafted', 80],
#  [2015, 'Bryce Dejean-Jones', 22, 'Undrafted', 80],
#  [2015, 'Stephan Hicks', 23, 'Undrafted', 80],
#  [2015, "J.J. O'Brien", 23, 'Undrafted', 80],
#  [2016, 'Dragan Bender', 18, 'Top15', 4],
#  [2016, 'Thon Maker', 19, 'Top15', 10],
#  [2016, 'George Papagiannis', 18, 'Top15', 13],
#  [2016, 'Juancho Hernangomez', 20, 'Top15', 15],
#  [2016, 'Guerschon Yabusele', 20, 'Top30', 16],
#  [2016, "DeAndre' Bembry", 21, 'Top30', 21],
#  [2016, 'Ante Zizic', 19, 'Top30', 23],
#  [2016, 'Timothe Luwawu-Cabarrot', 21, 'Top30', 24],
#  [2016, 'Furkan Korkmaz', 18, 'Top30', 26],
#  [2016, 'Ivica Zubac', 19, 'Top45', 32],
#  [2016, 'Rade Zagorac', 20, 'Top45', 35],
#  [2016, 'David Michineau', 22, 'Top45', 39],
#  [2016, 'Stephen Zimmerman', 19, 'Top45', 41],
#  [2016, 'Zhou Qi', 20, 'Top45', 43],
#  [2016, 'Isaia Cordinier', 19, 'Top45', 44],
#  [2016, 'Paul Zipser', 22, 'Top60', 48],
#  [2016, 'Petr Cornelie', 20, 'Top60', 53],
#  [2016, 'Kay Felder', 21, 'Top60', 54],
#  [2016, 'Zhelin Wang', 22, 'Top60', 57],
#  [2016, 'Yogi Ferrell', 23, 'Undrafted', 80],
#  [2016, 'Fred VanVleet', 22, 'Undrafted', 80],
#  [2016, 'Joshia Gray', 22, 'Undrafted', 80],
#  [2016, 'Mark Ogden', 21, 'Undrafted', 80],
#  [2016, "D'Vauntes Smith-Rivera", 23, 'Undrafted', 80],
#  [2016, 'Sheldon Mac', 23, 'Undrafted', 80],
#  [2016, 'Gracin Bakumanya', 18, 'Undrafted', 80],
#  [2016, 'Cat Barber', 21, 'Undrafted', 80],
#  [2016, 'Trey Freeman', 23, 'Undrafted', 80],
#  [2017, "De'Aaron Fox", 19, 'Top15', 5],
#  [2017, 'Frank Ntilikina', 18, 'Top15', 8],
#  [2017, 'Bam Adebayo', 19, 'Top15', 14],
#  [2017, 'Terrance Ferguson', 19, 'Top30', 21],
#  [2017, 'Ogugua Anunoby', 19, 'Top30', 23],
#  [2017, 'Anzejs Pasecniks', 21, 'Top30', 25],
#  [2017, 'Isaiah Hartenstein', 19, 'Top45', 43],
#  [2017, 'Vlatko Cancar', 20, 'Top60', 49],
#  [2017, 'Mathias Lessort', 21, 'Top60', 50],
#  [2017, 'Aleksandar Vezenkov', 21, 'Top60', 57],
#  [2017, 'Ognjen Jaramaz', 21, 'Top60', 58],
#  [2017, 'Alpha Kaba', 20, 'Top60', 60],
#  [2017, 'Jaylen Morris', 21, 'Undrafted', 80],
#  [2017, 'Steph Branch', 21, 'Undrafted', 80],
#  [2017, 'Yudai Baba', 21, 'Undrafted', 80],
#  [2017, 'Marko Guduric', 22, 'Undrafted', 80],
#  [2017, 'Tidjan Keita', 20, 'Undrafted', 80],
#  [2017, 'Eric Mika', 22, 'Undrafted', 80],
#  [2018, 'Luka Doncic', 19, 'Top15', 3],
#  [2018, 'Lonnie Walker', 19, 'Top30', 18],
#  [2018, 'Anfernee Simons', 19, 'Top30', 24],
#  [2018, 'Moe Wagner', 21, 'Top30', 25],
#  [2018, 'Dzanan Musa', 19, 'Top30', 29],
#  [2018, 'Elie Okobo', 20, 'Top45', 31],
#  [2018, "Devonte' Graham", 23, 'Top45', 34],
#  [2018, 'Mitchell Robinson', 20, 'Top45', 36],
#  [2018, 'Isaac Bonga', 18, 'Top45', 39],
#  [2018, 'Rodions Kurucs', 20, 'Top45', 40],
#  [2018, 'Yusuf Sanon', 18, 'Top45', 44],
#  [2018, "De'Anthony Melton", 20, 'Top60', 46],
#  [2018, 'Svi Mykhailiuk', 21, 'Top60', 47],
#  [2018, 'Shake Milton', 21, 'Top60', 54],
#  [2018, 'Arnoldas Kulboka', 20, 'Top60', 55],
#  [2018, 'Haywood Highsmith', 21, 'Undrafted', 80],
#  [2018, 'Emanuel Terry', 22, 'Undrafted', 80],
#  [2018, 'Tiwian Kendley', 23, 'Undrafted', 80],
#  [2018, 'Oleksandr Kobets', 22, 'Undrafted', 80],
#  [2018, 'Taren Sullivan', 22, 'Undrafted', 80],
#  [2018, 'Tyrius Walker', 22, 'Undrafted', 80],
#  [2018, 'Todd Withers', 22, 'Undrafted', 80],
#  [2018, 'Cam Reynolds', 23, 'Undrafted', 80],
#  [2018, 'Phil Carr', 22, 'Undrafted', 80],
#  [2018, 'Demetrius Denzel-Dyson', 23, 'Undrafted', 80],
#  [2018, 'Rob Gray', 24, 'Undrafted', 80],
#  [2018, 'Ismaila Kane', 20, 'Undrafted', 80],
#  [2019, 'Ja Morant', 19, 'Top15', 2],
#  [2019, "De'Andre Hunter", 21, 'Top15', 4],
#  [2019, 'Sekou Doumbouya', 18, 'Top15', 15],
#  [2019, 'Goga Bitadze', 19, 'Top30', 18],
#  [2019, 'Luka Samanic', 19, 'Top30', 19],
#  [2019, 'Darius Bazley', 19, 'Top30', 23],
#  [2019, 'KZ Okpala', 20, 'Top45', 32],
#  [2019, 'Didi Louzada', 19, 'Top45', 35],
#  [2019, 'Deividas Sirvydis', 19, 'Top45', 37],
#  [2019, 'Alen Smailagic', 18, 'Top45', 39],
#  [2019, 'Dewan Hernandez', 22, 'Top60', 59],
#  [2019, 'Vanja Marinkovic', 22, 'Top60', 60],
#  [2019, 'Shizz Alston', 22, 'Undrafted', 80],
#  [2019, 'Shaq Buchanan', 22, 'Undrafted', 80],
#  [2019, 'Christ Koumadje', 22, 'Undrafted', 80],
#  [2019, 'David Kramer', 22, 'Undrafted', 80],
#  [2019, 'Amir Hinton', 22, 'Undrafted', 80],
#  [2019, 'Daulton Hommes', 22, 'Undrafted', 80],
#  [2019, 'Jalen Lecque', 19, 'Undrafted', 80],
#  [2019, 'Matur Maker', 21, 'Undrafted', 80],
#  [2019, 'William McDowell-White', 21, 'Undrafted', 80],
#  [2019, 'Zach Norvell', 21, 'Undrafted', 80],
#  [2019, 'Simi Shittu', 19, 'Undrafted', 80],
#  [2019, "Tre'Shawn Thurman", 23, 'Undrafted', 80]]

# %%
# Most of the above have not played in NCAA, but some are errors
# This function returns all the players on sports-reference that have final seasons between 2005 and 2019, given
# their last name
def getPlayersHTML(lastName):
    url = f"https://www.sports-reference.com/cbb/players/{lastName}-index.html"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    allrows = soup.find_all('p')
    out = []
    for row in allrows:
        if row.find('small') is not None:
            start, end = re.findall(r'\d+', row.find('small').text)
            if (int(start) >= 2005) and (int(end) <= 2019):
                out.append([row.find('a').text, end, row.find('a').get('href')])

    return out

# %%
# Obtain all players who played NCAA between 2005-2019
allURL = []
for char in string.ascii_lowercase:
    allURL.extend(getPlayersHTML(char))

# %%
# If first name and last name found, then we can record the players
found = []
for i, row in enumerate(notFound):
    name = row[1]
    split_name = name.replace('.', '').split(' ')
    first, last = split_name[0], split_name[1]
    for j in allURL:
        counter = 0
        if (first in j[0]) and (last in j[0]) and str(row[0]) == j[1]:
            temp = row.copy()
            temp.append(j[2])
            found.append(temp)
            counter += 1
        if counter >= 2:
            print(j)

# %%
len(found)
# Out:
# 48

# %%
found[0]
# Out:
# [2009, 'Byron Mullens', 20, 'Top30', 24, '/cbb/players/bj-mullens-1.html']

# %%
out = []
for player in found:
    name, age, labelCat, labelPick, url = player[1], player[2], player[3], player[4], 'https://www.sports-reference.com' + player[5]
    try:
        row = scraping.scrapeRow(url)
        out.append([row[0], name, age] + row[2:] + [labelCat, labelPick])
    except:
        print(player)
# Out:
# [2009, 'Byron Mullens', 20, 'Top30', 24, '/cbb/players/bj-mullens-1.html']

# %%
data.extend(out)
len(data)
# Out:
# 1525

# %% [markdown]
# **Retrieved the maximum number players possible, 1525**
#
# **Save the output to a df now.**

# %%
colNames = scraping.getColNames('https://www.sports-reference.com/cbb/players/zion-williamson-1.html')
df = pd.DataFrame(data, columns= colNames)
df.to_csv('data/out.csv', index=False)

# %%
df.head()
# Out:
#                   ID             Name  Age Position Height Weight Season  \
# 0     andrew-bogut-1     Andrew Bogut   20  Forward    213    111   2005
# 1  marvin-williams-1  Marvin Williams   19  Forward    206    104   2005
# 2   deron-williams-1   Deron Williams   21    Guard    190     95   2005
# 3       chris-paul-1       Chris Paul   20    Guard    183     79   2005
# 4   raymond-felton-1   Raymond Felton   21    Guard    185     89   2005
#
#         School     Conf   G  ... STL% BLK%  TOV%  USG%  OWS  DWS    WS WS/40  \
# 0         Utah      MWC  35  ...       4.2  14.8  29.7  6.4  4.5  10.9  .358
# 1          UNC      ACC  36  ...       1.4  14.7  21.1  2.6  2.1   4.8  .239
# 2     Illinois  Big Ten  39  ...       0.5  19.3  22.5  2.1  2.5   4.6  .140
# 3  Wake Forest      ACC  32  ...       0.1  18.0  21.5  2.9  1.6   4.6  .171
# 4          UNC      ACC  36  ...       0.6  24.7  20.4  2.7  2.5   5.1  .179
#
#   DraftCategory DraftPick
# 0         Top15         1
# 1         Top15         2
# 2         Top15         3
# 3         Top15         4
# 4         Top15         5
#
# [5 rows x 54 columns]

# %% [markdown]
# **Some of the positions are subsets of existing positions, so we edit the feature**

# %%
df.loc[df['Position'] == 'Guard-Forward', 'Position'] = 'Guard'
df.loc[df['Position'] == 'Forward-Guard', 'Position'] = 'Forward'
df.loc[df['Position'] == 'Forward-Center', 'Position'] = 'Forward'
df.loc[df['Position'] == 'Center-Forward', 'Position'] = 'Center'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1525 entries, 0 to 1524
# Data columns (total 54 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             1525 non-null   object
#  1   Name           1525 non-null   object
#  2   Age            1525 non-null   int64
#  3   Position       1525 non-null   object
#  4   Height         1525 non-null   object
#  5   Weight         1525 non-null   object
#  6   Season         1525 non-null   object
#  7   School         1525 non-null   object
#  8   Conf           1525 non-null   object
#  9   G              1525 non-null   object
#  10  GS             1525 non-null   object
#  11  MP             1525 non-null   object
#  12  FG             1525 non-null   object
#  13  FGA            1525 non-null   object
#  14  FG%            1525 non-null   object
#  15  2P             1525 non-null   object
#  16  2PA            1525 non-null   object
#  17  2P%            1525 non-null   object
#  18  3P             1525 non-null   object
#  19  3PA            1525 non-null   object
#  20  3P%            1525 non-null   object
#  21  FT             1525 non-null   object
#  22  FTA            1525 non-null   object
#  23  FT%            1525 non-null   object
#  24  ORB            1525 non-null   object
#  25  DRB            1525 non-null   object
#  26  TRB            1525 non-null   object
#  27  AST            1525 non-null   object
#  28  STL            1525 non-null   object
#  29  BLK            1525 non-null   object
#  30  TOV            1525 non-null   object
#  31  PF             1525 non-null   object
#  32  PTS            1525 non-null   object
#  33  SOS            1525 non-null   object
#  34  PER            1525 non-null   object
#  35  TS%            1525 non-null   object
#  36  eFG%           1525 non-null   object
#  37  3PAr           1525 non-null   object
#  38  FTr            1525 non-null   object
#  39  PProd          1525 non-null   object
#  40  ORB%           1525 non-null   object
#  41  DRB%           1525 non-null   object
#  42  TRB%           1525 non-null   object
#  43  AST%           1525 non-null   object
#  44  STL%           1525 non-null   object
#  45  BLK%           1525 non-null   object
#  46  TOV%           1525 non-null   object
#  47  USG%           1525 non-null   object
#  48  OWS            1525 non-null   object
#  49  DWS            1525 non-null   object
#  50  WS             1525 non-null   object
#  51  WS/40          1525 non-null   object
#  52  DraftCategory  1525 non-null   object
#  53  DraftPick      1525 non-null   int64
# dtypes: int64(2), object(52)
# memory usage: 643.5+ KB

# %% [markdown]
# **Change the DraftCategory to integers for Torch**

# %%
from sklearn.preprocessing import LabelEncoder

lb_make = LabelEncoder()
target = lb_make.fit_transform(df['DraftCategory'])
df['DraftCategory'] = target

# %% [markdown]
# **One-Hot Encoding for Position and Conf**

# %%
positions = pd.get_dummies(df['Position'])
conf = pd.get_dummies(df['Conf'])
df = pd.concat([df[['ID', 'Name', 'Age']], 
                positions, conf, 
                df[['Height', 'Weight', 'Season']],
                df.iloc[:, 9:54]],
                axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1525 entries, 0 to 1524
# Data columns (total 89 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             1525 non-null   object
#  1   Name           1525 non-null   object
#  2   Age            1525 non-null   int64
#  3   Center         1525 non-null   uint8
#  4   Forward        1525 non-null   uint8
#  5   Guard          1525 non-null   uint8
#  6   A-10           1525 non-null   uint8
#  7   A-Sun          1525 non-null   uint8
#  8   AAC            1525 non-null   uint8
#  9   ACC            1525 non-null   uint8
#  10  AEC            1525 non-null   uint8
#  11  Big 12         1525 non-null   uint8
#  12  Big East       1525 non-null   uint8
#  13  Big Sky        1525 non-null   uint8
#  14  Big South      1525 non-null   uint8
#  15  Big Ten        1525 non-null   uint8
#  16  Big West       1525 non-null   uint8
#  17  CAA            1525 non-null   uint8
#  18  CUSA           1525 non-null   uint8
#  19  Horizon        1525 non-null   uint8
#  20  Ind            1525 non-null   uint8
#  21  Ivy            1525 non-null   uint8
#  22  MAAC           1525 non-null   uint8
#  23  MAC            1525 non-null   uint8
#  24  MEAC           1525 non-null   uint8
#  25  MVC            1525 non-null   uint8
#  26  MWC            1525 non-null   uint8
#  27  Mid-Cont       1525 non-null   uint8
#  28  NEC            1525 non-null   uint8
#  29  OVC            1525 non-null   uint8
#  30  Pac-10         1525 non-null   uint8
#  31  Pac-12         1525 non-null   uint8
#  32  Patriot        1525 non-null   uint8
#  33  SEC            1525 non-null   uint8
#  34  SWAC           1525 non-null   uint8
#  35  Southern       1525 non-null   uint8
#  36  Southland      1525 non-null   uint8
#  37  Summit         1525 non-null   uint8
#  38  Sun Belt       1525 non-null   uint8
#  39  WAC            1525 non-null   uint8
#  40  WCC            1525 non-null   uint8
#  41  Height         1525 non-null   object
#  42  Weight         1525 non-null   object
#  43  Season         1525 non-null   object
#  44  G              1525 non-null   object
#  45  GS             1525 non-null   object
#  46  MP             1525 non-null   object
#  47  FG             1525 non-null   object
#  48  FGA            1525 non-null   object
#  49  FG%            1525 non-null   object
#  50  2P             1525 non-null   object
#  51  2PA            1525 non-null   object
#  52  2P%            1525 non-null   object
#  53  3P             1525 non-null   object
#  54  3PA            1525 non-null   object
#  55  3P%            1525 non-null   object
#  56  FT             1525 non-null   object
#  57  FTA            1525 non-null   object
#  58  FT%            1525 non-null   object
#  59  ORB            1525 non-null   object
#  60  DRB            1525 non-null   object
#  61  TRB            1525 non-null   object
#  62  AST            1525 non-null   object
#  63  STL            1525 non-null   object
#  64  BLK            1525 non-null   object
#  65  TOV            1525 non-null   object
#  66  PF             1525 non-null   object
#  67  PTS            1525 non-null   object
#  68  SOS            1525 non-null   object
#  69  PER            1525 non-null   object
#  70  TS%            1525 non-null   object
#  71  eFG%           1525 non-null   object
#  72  3PAr           1525 non-null   object
#  73  FTr            1525 non-null   object
#  74  PProd          1525 non-null   object
#  75  ORB%           1525 non-null   object
#  76  DRB%           1525 non-null   object
#  77  TRB%           1525 non-null   object
#  78  AST%           1525 non-null   object
#  79  STL%           1525 non-null   object
#  80  BLK%           1525 non-null   object
#  81  TOV%           1525 non-null   object
#  82  USG%           1525 non-null   object
#  83  OWS            1525 non-null   object
#  84  DWS            1525 non-null   object
#  85  WS             1525 non-null   object
#  86  WS/40          1525 non-null   object
#  87  DraftCategory  1525 non-null   int32
#  88  DraftPick      1525 non-null   int64
# dtypes: int32(1), int64(2), object(48), uint8(38)
# memory usage: 658.4+ KB

# %% [markdown]
# **Change the type of the statistics from string to numeric**

# %%
for col in df.columns[41: ]:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1525 entries, 0 to 1524
# Data columns (total 89 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             1525 non-null   object
#  1   Name           1525 non-null   object
#  2   Age            1525 non-null   int64
#  3   Center         1525 non-null   uint8
#  4   Forward        1525 non-null   uint8
#  5   Guard          1525 non-null   uint8
#  6   A-10           1525 non-null   uint8
#  7   A-Sun          1525 non-null   uint8
#  8   AAC            1525 non-null   uint8
#  9   ACC            1525 non-null   uint8
#  10  AEC            1525 non-null   uint8
#  11  Big 12         1525 non-null   uint8
#  12  Big East       1525 non-null   uint8
#  13  Big Sky        1525 non-null   uint8
#  14  Big South      1525 non-null   uint8
#  15  Big Ten        1525 non-null   uint8
#  16  Big West       1525 non-null   uint8
#  17  CAA            1525 non-null   uint8
#  18  CUSA           1525 non-null   uint8
#  19  Horizon        1525 non-null   uint8
#  20  Ind            1525 non-null   uint8
#  21  Ivy            1525 non-null   uint8
#  22  MAAC           1525 non-null   uint8
#  23  MAC            1525 non-null   uint8
#  24  MEAC           1525 non-null   uint8
#  25  MVC            1525 non-null   uint8
#  26  MWC            1525 non-null   uint8
#  27  Mid-Cont       1525 non-null   uint8
#  28  NEC            1525 non-null   uint8
#  29  OVC            1525 non-null   uint8
#  30  Pac-10         1525 non-null   uint8
#  31  Pac-12         1525 non-null   uint8
#  32  Patriot        1525 non-null   uint8
#  33  SEC            1525 non-null   uint8
#  34  SWAC           1525 non-null   uint8
#  35  Southern       1525 non-null   uint8
#  36  Southland      1525 non-null   uint8
#  37  Summit         1525 non-null   uint8
#  38  Sun Belt       1525 non-null   uint8
#  39  WAC            1525 non-null   uint8
#  40  WCC            1525 non-null   uint8
#  41  Height         1525 non-null   int64
#  42  Weight         1525 non-null   int64
#  43  Season         1525 non-null   int64
#  44  G              1525 non-null   int64
#  45  GS             1525 non-null   int64
#  46  MP             1525 non-null   float64
#  47  FG             1525 non-null   float64
#  48  FGA            1525 non-null   float64
#  49  FG%            1525 non-null   float64
#  50  2P             1525 non-null   float64
#  51  2PA            1525 non-null   float64
#  52  2P%            1525 non-null   float64
#  53  3P             1525 non-null   float64
#  54  3PA            1525 non-null   float64
#  55  3P%            1369 non-null   float64
#  56  FT             1525 non-null   float64
#  57  FTA            1525 non-null   float64
#  58  FT%            1525 non-null   float64
#  59  ORB            1525 non-null   float64
#  60  DRB            1525 non-null   float64
#  61  TRB            1525 non-null   float64
#  62  AST            1525 non-null   float64
#  63  STL            1525 non-null   float64
#  64  BLK            1525 non-null   float64
#  65  TOV            1525 non-null   float64
#  66  PF             1525 non-null   float64
#  67  PTS            1525 non-null   float64
#  68  SOS            1523 non-null   float64
#  69  PER            969 non-null    float64
#  70  TS%            1525 non-null   float64
#  71  eFG%           1525 non-null   float64
#  72  3PAr           1525 non-null   float64
#  73  FTr            1525 non-null   float64
#  74  PProd          1071 non-null   float64
#  75  ORB%           1072 non-null   float64
#  76  DRB%           1072 non-null   float64
#  77  TRB%           1381 non-null   float64
#  78  AST%           1381 non-null   float64
#  79  STL%           1072 non-null   float64
#  80  BLK%           1381 non-null   float64
#  81  TOV%           1522 non-null   float64
#  82  USG%           1381 non-null   float64
#  83  OWS            1520 non-null   float64
#  84  DWS            1520 non-null   float64
#  85  WS             1520 non-null   float64
#  86  WS/40          1520 non-null   float64
#  87  DraftCategory  1525 non-null   int32
#  88  DraftPick      1525 non-null   int64
# dtypes: float64(41), int32(1), int64(7), object(2), uint8(38)
# memory usage: 658.4+ KB

# %% [markdown]
# **5 recorsd have no OWS and DWS. Remove them**

# %%
df = df[df['OWS'].isna() == False]

# %% [markdown]
# **We already have FG, FGA. Thus can remove FG%. Same for 2P, 3P and FT**

# %%
df = df.drop(columns = ['FG%', '2P%', '3P%', 'FT%'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1520 entries, 0 to 1524
# Data columns (total 85 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             1520 non-null   object
#  1   Name           1520 non-null   object
#  2   Age            1520 non-null   int64
#  3   Center         1520 non-null   uint8
#  4   Forward        1520 non-null   uint8
#  5   Guard          1520 non-null   uint8
#  6   A-10           1520 non-null   uint8
#  7   A-Sun          1520 non-null   uint8
#  8   AAC            1520 non-null   uint8
#  9   ACC            1520 non-null   uint8
#  10  AEC            1520 non-null   uint8
#  11  Big 12         1520 non-null   uint8
#  12  Big East       1520 non-null   uint8
#  13  Big Sky        1520 non-null   uint8
#  14  Big South      1520 non-null   uint8
#  15  Big Ten        1520 non-null   uint8
#  16  Big West       1520 non-null   uint8
#  17  CAA            1520 non-null   uint8
#  18  CUSA           1520 non-null   uint8
#  19  Horizon        1520 non-null   uint8
#  20  Ind            1520 non-null   uint8
#  21  Ivy            1520 non-null   uint8
#  22  MAAC           1520 non-null   uint8
#  23  MAC            1520 non-null   uint8
#  24  MEAC           1520 non-null   uint8
#  25  MVC            1520 non-null   uint8
#  26  MWC            1520 non-null   uint8
#  27  Mid-Cont       1520 non-null   uint8
#  28  NEC            1520 non-null   uint8
#  29  OVC            1520 non-null   uint8
#  30  Pac-10         1520 non-null   uint8
#  31  Pac-12         1520 non-null   uint8
#  32  Patriot        1520 non-null   uint8
#  33  SEC            1520 non-null   uint8
#  34  SWAC           1520 non-null   uint8
#  35  Southern       1520 non-null   uint8
#  36  Southland      1520 non-null   uint8
#  37  Summit         1520 non-null   uint8
#  38  Sun Belt       1520 non-null   uint8
#  39  WAC            1520 non-null   uint8
#  40  WCC            1520 non-null   uint8
#  41  Height         1520 non-null   int64
#  42  Weight         1520 non-null   int64
#  43  Season         1520 non-null   int64
#  44  G              1520 non-null   int64
#  45  GS             1520 non-null   int64
#  46  MP             1520 non-null   float64
#  47  FG             1520 non-null   float64
#  48  FGA            1520 non-null   float64
#  49  2P             1520 non-null   float64
#  50  2PA            1520 non-null   float64
#  51  3P             1520 non-null   float64
#  52  3PA            1520 non-null   float64
#  53  FT             1520 non-null   float64
#  54  FTA            1520 non-null   float64
#  55  ORB            1520 non-null   float64
#  56  DRB            1520 non-null   float64
#  57  TRB            1520 non-null   float64
#  58  AST            1520 non-null   float64
#  59  STL            1520 non-null   float64
#  60  BLK            1520 non-null   float64
#  61  TOV            1520 non-null   float64
#  62  PF             1520 non-null   float64
#  63  PTS            1520 non-null   float64
#  64  SOS            1520 non-null   float64
#  65  PER            969 non-null    float64
#  66  TS%            1520 non-null   float64
#  67  eFG%           1520 non-null   float64
#  68  3PAr           1520 non-null   float64
#  69  FTr            1520 non-null   float64
#  70  PProd          1071 non-null   float64
#  71  ORB%           1071 non-null   float64
#  72  DRB%           1071 non-null   float64
#  73  TRB%           1380 non-null   float64
#  74  AST%           1380 non-null   float64
#  75  STL%           1071 non-null   float64
#  76  BLK%           1380 non-null   float64
#  77  TOV%           1520 non-null   float64
#  78  USG%           1380 non-null   float64
#  79  OWS            1520 non-null   float64
#  80  DWS            1520 non-null   float64
#  81  WS             1520 non-null   float64
#  82  WS/40          1520 non-null   float64
#  83  DraftCategory  1520 non-null   int32
#  84  DraftPick      1520 non-null   int64
# dtypes: float64(37), int32(1), int64(7), object(2), uint8(38)
# memory usage: 620.5+ KB

# %%
df.to_csv('data/full.csv', index=False)

# %% [markdown]
# **Different subsets of the original data, as some columns have missing values.**

# %%
mostSpecific = df[df.notnull().all(1)]
mostSpecific = mostSpecific.loc[:, (mostSpecific != mostSpecific.iloc[0]).any()]

# %%
secondMost = df.drop(columns = ['PER', 'PProd', 'ORB%', 'DRB%', 'STL%'])
secondMost = secondMost[secondMost.notnull().all(1)]
secondMost = secondMost.loc[:, (secondMost != secondMost.iloc[0]).any()]

# %%
leastSpecific = df.drop(columns = ['PER', 'PProd', 'ORB%', 'DRB%', 'STL%', 'TRB%', 'AST%', 'BLK%', 'USG%'])
leastSpecific = leastSpecific.loc[:, (leastSpecific != leastSpecific.iloc[0]).any()]

# %% [markdown]
# **Save these subsets for the model**

# %%
mostSpecific.to_csv('data/mostSpecific.csv', index=False)
secondMost.to_csv('data/secondMost.csv', index=False)
leastSpecific.to_csv('data/leastSpecific.csv', index=False)
